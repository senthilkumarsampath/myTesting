# %%
import spacy, re
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

with open("/Users/senthil/Desktop/Senthil/myTesting/Project_Creation/Spacy/Burling_notes_SG.txt", "r") as f:
    text = f.read()
    print(text)

# %%
doc = nlp(text)
print(doc)

# %%
for tocken in doc[:100]:
    print(f"{tocken.text}: {tocken.ent_type_}")
# Out:
# PROJECT: ORG
# MANAGEMENT: ORG
# -: ORG
# HANDOVER: ORG
# NOTES:
#
#
# :
# Handover:
# Notes:
# ::
#
#
# :
# Book:
# title:
# ::
# Research:
# Handbook:
# on:
# International:
# Insurance:
# Law:
# and:
# Regulation:
#
# :
# Author:
# /:
# Eds:
# ::
# Julian:
# Burling:
# and:
# Kevin: PERSON
# Lazarus: PERSON
#
# :
# ISBN:
# /:
# E:
# -:
# ISBN:
# ::
# 978: CARDINAL
# 1: QUANTITY
# 80220: QUANTITY
# 588: QUANTITY
# 6: QUANTITY
# /: QUANTITY
# 978: QUANTITY
# 1: QUANTITY
# 80220: QUANTITY
# 589: QUANTITY
# 3:
#
# :
# e:
# -:
# Book:
# subject:
# collection:
# ::
# Law:
#
# :
# Edited:
# work:
# or:
# single:
# author:
# ?:
# ::
# Edited:
#
# :
# Number:
# of:
# files:
# ::
# Admin:
# folder:
# ::
# 4: CARDINAL
# ;:
# MS: ORG
# files:
# ::
# 39: CARDINAL
#
# :
# Composition:
# instructions:
# ::
# EE10:
# (:
# law:
# ):
#
# :
# Series: WORK_OF_ART
# :: WORK_OF_ART
# Research: WORK_OF_ART
# Handbooks: WORK_OF_ART
# in:
# Financial: ORG
# Law: ORG
#
# : ORG
# Word: ORG
# count:
# ::
