# %%
import docx
from docx.shared import Pt
import lxml 
from tabulate import tabulate

# Open the word document
doc = docx.Document("/Users/senthil/Desktop/Senthil/myTesting/python_scripts/Table_width_adjusment/RL_08_WOLI_C001.docx")

# Iterate through all tables in the document
em = 2048
average_char_width = 4

for i, table in enumerate(doc.tables):
    print("Table", i+1)
    column_count = len(table._element.xpath('.//w:gridCol'))
    print("Number of Columns: ", column_count)
    data = []
    # Iterate through all columns in the table

    for j in range(column_count):
        column_text = []
        for row in table.rows:
            if j < len(row.cells):
                cell_text = row.cells[j].text
                if cell_text != "":
                    column_text.append(cell_text)

        average_chars = int(sum(len(x) for x in column_text) / len(column_text))
        min_chars = min(len(x) for x in column_text)
        max_chars = max(len(x) for x in column_text)

        width_pt = table.columns[j].width / 12700
        no_of_rows = len(table.rows)
        count_rows_above_min_max = 0

        less_than_avg = 0
        greater_than_avg = 0
        
        for text in column_text:
            if len(text) < average_chars:
                less_than_avg += 1
            elif len(text) > average_chars:
                greater_than_avg += 1

        for row in table.rows:
            if all(cell.text == "" for cell in row.cells):
                continue
            if all(min_chars <= len(cell.text) <= max_chars for cell in row.cells):
                count_rows_above_min_max += 1
                
      
        if less_than_avg > greater_than_avg:
            new_width = average_chars * average_char_width
            table.columns[j].width=Pt(new_width)
            new_updated_width = table.columns[j].width / 12700
        else:
            new_width = average_chars * average_char_width
            table.columns[j].width=Pt(new_width)
            new_updated_width = table.columns[j].width / 12700

        doc.save("Chapter3_tables_updated.docx")
               
        data.append(["Column "+str(j+1),width_pt,no_of_rows,average_chars,min_chars,max_chars,less_than_avg,greater_than_avg, new_width, new_updated_width])
    print(tabulate(data, headers=["Columns", "Width", "Rows","Avg_Chars", "Min_Chars", "Max_Chars","R<Avg.","R>Avg.","New_Width", "U-width"],tablefmt="fancy_grid"))
# Out:
# Table 1
# Number of Columns:  5
# ╒═══════════╤═════════╤════════╤═════════════╤═════════════╤═════════════╤══════════╤══════════╤═════════════╤═══════════╕
# │ Columns   │   Width │   Rows │   Avg_Chars │   Min_Chars │   Max_Chars │   R<Avg. │   R>Avg. │   New_Width │   U-width │
# ╞═══════════╪═════════╪════════╪═════════════╪═════════════╪═════════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ Column 1  │   97.55 │     15 │           8 │           3 │          48 │       11 │        4 │          32 │        32 │
# ├───────────┼─────────┼────────┼─────────────┼─────────────┼─────────────┼──────────┼──────────┼─────────────┼───────────┤
# │ Column 2  │   77.95 │     15 │          13 │           4 │          18 │        3 │       12 │          52 │        52 │
# ├───────────┼─────────┼────────┼─────────────┼─────────────┼─────────────┼──────────┼──────────┼─────────────┼───────────┤
# ...

# %%
import docx
from docx.shared import Pt
import lxml 
from tabulate import tabulate

# Open the word document
doc = docx.Document("Chapter 3.docx")

# Iterate through all tables in the document
em = 2048
average_char_width = 5

for i, table in enumerate(doc.tables):
    print("Table", i+1)
    column_count = len(table._element.xpath('.//w:gridCol'))
    print("Number of Columns: ", column_count)
    data = []
    # Iterate through all columns in the table

    for j in range(column_count):
        column_text = []
        for row in table.rows:
            if j < len(row.cells):
                cell_text = row.cells[j].text
                if cell_text != "":
                    column_text.append(cell_text)

        average_chars = int(sum(len(x) for x in column_text) / len(column_text))
        min_chars = min(len(x) for x in column_text)
        max_chars = max(len(x) for x in column_text)

        width_pt = table.columns[j].width / 12700
        no_of_rows = len(table.rows)
       
        less_than_avg = 1
        greater_than_avg = 1
        for text in column_text:
            if len(text) < average_chars:
                less_than_avg += 1
            elif len(text) > average_chars:
                greater_than_avg += 1

        # for row in table.rows:
        #     if all(cell.text == "" for cell in row.cells):
        #         continue
        #     if all(min_chars <= len(cell.text) <= max_chars for cell in row.cells):
        #         count_rows_above_min_max += 1
                
        sum_less_than_avg = sum(len(x) for x in column_text if len(x) < average_chars)
        sum_greater_than_avg = sum(len(x) for x in column_text if len(x) > average_chars)

        # print(f"less_than_avg: {less_than_avg}, greater_than_avg: {greater_than_avg}")
        # print(f"sum_less_than_avg: {sum_less_than_avg}, sum_greater_than_avg: {sum_greater_than_avg} ")

        if  sum_greater_than_avg > sum_less_than_avg:
            new_width = int((sum_greater_than_avg/greater_than_avg)*average_char_width)
            if (new_width/average_char_width)>100:
                new_width = int(new_width/average_char_width/3)*average_char_width
                table.columns[j].width=Pt(new_width)
                new_updated_width = table.columns[j].width / 12700
        else:
            new_width = int((sum_less_than_avg/less_than_avg)*average_char_width)
            if (new_width/average_char_width)>100:
                new_width = int(new_width/average_char_width/3)*average_char_width
                table.columns[j].width=Pt(new_width)
                new_updated_width = table.columns[j].width / 12700

        doc.save("Chapter3_tables_updated.docx")
               
        data.append(["Column "+str(j+1),no_of_rows,average_chars,min_chars,max_chars,less_than_avg,greater_than_avg, sum_less_than_avg,sum_greater_than_avg,new_width])
    print(tabulate(data, headers=["Columns", "Rows","Avg_Chars", "Min_Chars", "Max_Chars","R<Avg.","R>Avg.","Sum(R<Avg)","Sum(R>Avg)","New Avg."])) #tablefmt="fancy_grid"
# Out:
# Table 1
# Number of Columns:  2
# Columns      Rows    Avg_Chars    Min_Chars    Max_Chars    R<Avg.    R>Avg.    Sum(R<Avg)    Sum(R>Avg)    New Avg.
# ---------  ------  -----------  -----------  -----------  --------  --------  ------------  ------------  ----------
# Column 1        7           21           18           27         3         4            37            72          90
# Column 2        7           19           12           30         5         3            58            60         100
# Table 2
# Number of Columns:  5
# Columns      Rows    Avg_Chars    Min_Chars    Max_Chars    R<Avg.    R>Avg.    Sum(R<Avg)    Sum(R>Avg)    New Avg.
# ---------  ------  -----------  -----------  -----------  --------  --------  ------------  ------------  ----------
# Column 1      101            1            1            3         1        92             0           183           9
# ...
