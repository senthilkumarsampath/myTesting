# %%
import os
import logging
import csv
import xml.etree.ElementTree as ET
from docx_extraction import extract_docx_properties
from docx import Document

def process_folder(folder_path, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.docx'):
                input_file_path = os.path.join(root, file)
                output_csv_path = os.path.join(output_folder, os.path.splitext(file)[0] + '.csv')
                extract_and_save_properties(input_file_path, output_csv_path)

def extract_and_save_properties(input_file_path, output_csv_path):
    logging.info(f"Started to extract the docx properties from {input_file_path}")
    doc = Document(input_file_path)
    remove_empty_paragraphs(doc)
    doc.save(input_file_path)  # Save the cleaned document
    para_properties_xml = extract_docx_properties(input_file_path)
    if para_properties_xml:
        logging.info(f"Converting properties XML to CSV: {output_csv_path}")
        xml_to_csv(para_properties_xml, output_csv_path)
    else:
        logging.warning(f"No properties extracted from {input_file_path}")

def xml_to_csv(para_properties_xml, output_csv_path):
    root = ET.fromstring(para_properties_xml)
    properties_list = []
    for para in root.findall('ParagraphProperties'):
        properties_dict = {}
        for prop in para:
            properties_dict[prop.tag] = prop.text
        properties_list.append(properties_dict)
    
    fieldnames = properties_list[0].keys() if properties_list else []
    with open(output_csv_path, 'w', newline='', encoding='utf-8-sig') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(properties_list)

def remove_empty_paragraphs(doc):
    for para in doc.paragraphs[:]:
        if not para.text.strip():
            doc._element.body.remove(para._element)

if __name__ == "__main__":
    folder_path = '/Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx'
    output_folder = '/Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset'
    process_folder(folder_path, output_folder)

# %%
import os
import logging
import csv
import xml.etree.ElementTree as ET
from docx_extraction import extract_docx_properties
from docx import Document

def process_folder(folder_path, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.docx'):
                input_file_path = os.path.join(root, file)
                output_csv_path = os.path.join(output_folder, os.path.splitext(file)[0] + '.csv')
                try:
                    extract_and_save_properties(input_file_path, output_csv_path)
                except Exception as e:
                    logging.warning(f"Error processing file {input_file_path}: {str(e)}")

def extract_and_save_properties(input_file_path, output_csv_path):
    logging.info(f"Started to extract the docx properties from {input_file_path}")
    doc = Document(input_file_path)
    remove_empty_paragraphs(doc)
    doc.save(input_file_path)  # Save the cleaned document
    try:
        para_properties_xml = extract_docx_properties(input_file_path)
        if para_properties_xml:
            logging.info(f"Converting properties XML to CSV: {output_csv_path}")
            xml_to_csv(para_properties_xml, output_csv_path)
        else:
            logging.warning(f"No properties extracted from {input_file_path}")
    except Exception as e:
        logging.warning(f"Error extracting properties from {input_file_path}: {str(e)}")

def xml_to_csv(para_properties_xml, output_csv_path):
    try:
        root = ET.fromstring(para_properties_xml)
        properties_list = []
        for para in root.findall('ParagraphProperties'):
            properties_dict = {}
            for prop in para:
                properties_dict[prop.tag] = prop.text
            properties_list.append(properties_dict)
        
        fieldnames = properties_list[0].keys() if properties_list else []
        with open(output_csv_path, 'w', newline='', encoding='utf-8-sig') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(properties_list)
    except Exception as e:
        logging.warning(f"Error converting properties XML to CSV: {str(e)}")

def remove_empty_paragraphs(doc):
    for para in doc.paragraphs[:]:
        if not para.text.strip():
            doc._element.body.remove(para._element)

if __name__ == "__main__":
    folder_path = '/Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx'
    output_folder = '/Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset'
    process_folder(folder_path, output_folder)
# Out:
# 2024-02-10 22:08:53 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ESE_20236882.docx
# 2024-02-10 22:08:53 INFO     Started creating the docx object
# 2024-02-10 22:08:53 INFO     Extracting the properties of the document
# 2024-02-10 22:08:53 INFO     Started processing the components to extract the properties
# 2024-02-10 22:08:55 INFO     Writing the extracted properties into XML
# 2024-02-10 22:08:55 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ESE_20236882.csv
# 2024-02-10 22:08:55 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ETJ_230108.docx
# 2024-02-10 22:08:55 INFO     Started creating the docx object
# 2024-02-10 22:08:55 INFO     Extracting the properties of the document
# 2024-02-10 22:08:55 INFO     Started processing the components to extract the properties
# 2024-02-10 22:08:58 INFO     Writing the extracted properties into XML
# 2024-02-10 22:08:58 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ETJ_230108.csv
# 2024-02-10 22:08:58 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_njb_03920.docx
# 2024-02-10 22:08:58 INFO     Started creating the docx object
# 2024-02-10 22:08:58 INFO     Extracting the properties of the document
# 2024-02-10 22:08:58 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:00 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:00 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_njb_03920.csv
# 2024-02-10 22:09:00 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/AOTT_20230065.docx
# 2024-02-10 22:09:00 INFO     Started creating the docx object
# 2024-02-10 22:09:00 INFO     Extracting the properties of the document
# 2024-02-10 22:09:00 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:03 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:03 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/AOTT_20230065.csv
# 2024-02-10 22:09:03 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/JIAO_20231084.docx
# 2024-02-10 22:09:03 INFO     Started creating the docx object
# 2024-02-10 22:09:03 INFO     Extracting the properties of the document
# 2024-02-10 22:09:03 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:04 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:04 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/JIAO_20231084.csv
# 2024-02-10 22:09:04 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/REM_230024.docx
# 2024-02-10 22:09:05 INFO     Started creating the docx object
# 2024-02-10 22:09:05 INFO     Extracting the properties of the document
# 2024-02-10 22:09:05 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:13 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:13 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/REM_230024.csv
# 2024-02-10 22:09:13 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TBE_20230192.docx
# 2024-02-10 22:09:13 INFO     Started creating the docx object
# 2024-02-10 22:09:13 INFO     Extracting the properties of the document
# 2024-02-10 22:09:13 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:18 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:18 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TBE_20230192.csv
# 2024-02-10 22:09:18 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/AJC_AJC-2023-701_R1RESUBMISSION-3962.docx
# 2024-02-10 22:09:18 INFO     Started creating the docx object
# 2024-02-10 22:09:18 INFO     Extracting the properties of the document
# 2024-02-10 22:09:18 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:19 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:19 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/AJC_AJC-2023-701_R1RESUBMISSION-3962.csv
# 2024-02-10 22:09:19 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_jav_03182.docx
# 2024-02-10 22:09:19 INFO     Started creating the docx object
# 2024-02-10 22:09:19 INFO     Extracting the properties of the document
# 2024-02-10 22:09:19 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:31 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:31 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_jav_03182.csv
# 2024-02-10 22:09:31 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TR_20230337.docx
# 2024-02-10 22:09:31 INFO     Started creating the docx object
# 2024-02-10 22:09:31 INFO     Extracting the properties of the document
# 2024-02-10 22:09:31 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:33 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:33 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TR_20230337.csv
# 2024-02-10 22:09:33 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/CRDS_20220044.docx
# 2024-02-10 22:09:33 INFO     Started creating the docx object
# 2024-02-10 22:09:33 INFO     Extracting the properties of the document
# 2024-02-10 22:09:33 INFO     Started processing the components to extract the properties
# 2024-02-10 22:09:36 INFO     Writing the extracted properties into XML
# 2024-02-10 22:09:36 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/CRDS_20220044.csv
# 2024-02-10 22:09:36 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/
INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/RISS_20230020.docx
# 2024-02-10 22:10:47 INFO     Started creating the docx object
# 2024-02-10 22:10:47 INFO     Extracting the properties of the document
# 2024-02-10 22:10:47 INFO     Started processing the components to extract the properties
# 2024-02-10 22:10:49 INFO     Writing the extracted properties into XML
# 2024-02-10 22:10:49 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/RISS_20230020.csv
# 2024-02-10 22:10:49 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_ecog_06852.docx
# 2024-02-10 22:10:49 INFO     Started creating the docx object
# 2024-02-10 22:10:50 INFO     Extracting the properties of the document
# 2024-02-10 22:10:50 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:04 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:04 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_ecog_06852.csv
# 2024-02-10 22:11:04 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TAP_23136.docx
# 2024-02-10 22:11:04 INFO     Started creating the docx object
# 2024-02-10 22:11:04 INFO     Extracting the properties of the document
# 2024-02-10 22:11:04 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:06 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:06 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TAP_23136.csv
# 2024-02-10 22:11:06 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_oik_10181.docx
# 2024-02-10 22:11:06 INFO     Started creating the docx object
# 2024-02-10 22:11:06 INFO     Extracting the properties of the document
# 2024-02-10 22:11:06 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:13 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:13 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_oik_10181.csv
# 2024-02-10 22:11:13 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ELECT_20230048.docx
# 2024-02-10 22:11:13 INFO     Started creating the docx object
# 2024-02-10 22:11:13 INFO     Extracting the properties of the document
# 2024-02-10 22:11:13 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:17 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:17 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ELECT_20230048.csv
# 2024-02-10 22:11:17 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EOR_220144.docx
# 2024-02-10 22:11:17 INFO     Started creating the docx object
# 2024-02-10 22:11:17 INFO     Extracting the properties of the document
# 2024-02-10 22:11:17 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:21 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:21 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EOR_220144.csv
# 2024-02-10 22:11:21 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ESE_2023003.docx
# 2024-02-10 22:11:21 INFO     Started creating the docx object
# 2024-02-10 22:11:21 INFO     Extracting the properties of the document
# 2024-02-10 22:11:21 INFO     Started processing the components to extract the properties
# 2024-02-10 22:11:22 INFO     Writing the extracted properties into XML
# 2024-02-10 22:11:22 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ESE_2023003.csv
# 2024-02-10 22:11:22 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ERP_20230388.docx
# 2024-02-10 22:11:22 INFO     Started creating the docx object
# 2024-02-10 22:11:22 INFO     Extracting the properties of the document
# 2024-02-10 22:11:22 INFO     Started processing the components to extract the properties
# 2024-02-10 22:13:19 INFO     Writing the extracted properties into XML
# 2024-02-10 22:13:19 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ERP_20230388.csv
# 2024-02-10 22:13:19 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/PCP_20230772.docx
# 2024-02-10 22:13:19 INFO     Started creating the docx object
# 2024-02-10 22:13:19 INFO     Extracting the properties of the document
# 2024-02-10 22:13:19 INFO     Started processing the components to extract the properties
# 2024-02-10 22:13:20 INFO     Writing the extracted properties into XML
# 2024-02-10 22:13:20 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/PCP_20230772.csv
# 2024-02-10 22:13:20 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/
INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TJCN_TJCN-2023-11_R1RESUBMISSION-149.csv
# 2024-02-10 22:15:01 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ECC_230403.docx
# 2024-02-10 22:15:01 INFO     Started creating the docx object
# 2024-02-10 22:15:01 INFO     Extracting the properties of the document
# 2024-02-10 22:15:01 INFO     Started processing the components to extract the properties
# 2024-02-10 22:15:07 INFO     Writing the extracted properties into XML
# 2024-02-10 22:15:07 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ECC_230403.csv
# 2024-02-10 22:15:07 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TAP_20230136.docx
# 2024-02-10 22:15:07 INFO     Started creating the docx object
# 2024-02-10 22:15:07 INFO     Extracting the properties of the document
# 2024-02-10 22:15:07 INFO     Started processing the components to extract the properties
# 2024-02-10 22:15:08 INFO     Writing the extracted properties into XML
# 2024-02-10 22:15:08 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TAP_20230136.csv
# 2024-02-10 22:15:08 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TJCN_20230149.docx
# 2024-02-10 22:15:08 INFO     Started creating the docx object
# 2024-02-10 22:15:09 INFO     Extracting the properties of the document
# 2024-02-10 22:15:09 INFO     Started processing the components to extract the properties
# ...
# 2024-02-11 09:55:40 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/JIAO_20231269.docx
# 2024-02-11 09:55:40 INFO     Started creating the docx object
# 2024-02-11 09:55:40 INFO     Extracting the properties of the document
# 2024-02-11 09:55:40 INFO     Started processing the components to extract the properties
# 2024-02-11 09:55:44 INFO     Writing the extracted properties into XML
# 2024-02-11 09:55:44 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/JIAO_20231269.csv
# 2024-02-11 09:55:44 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_oik_10301.docx
# 2024-02-11 09:55:44 INFO     Started creating the docx object
# 2024-02-11 09:55:44 INFO     Extracting the properties of the document
# 2024-02-11 09:55:44 INFO     Started processing the components to extract the properties
# 2024-02-11 09:55:50 INFO     Writing the extracted properties into XML
# 2024-02-11 09:55:50 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_oik_10301.csv
# 2024-02-11 09:55:50 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ERC_230063.docx
# 2024-02-11 09:55:50 INFO     Started creating the docx object
# 2024-02-11 09:55:51 INFO     Extracting the properties of the document
# 2024-02-11 09:55:51 INFO     Started processing the components to extract the properties
# 2024-02-11 09:55:55 INFO     Writing the extracted properties into XML
# 2024-02-11 09:55:55 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ERC_230063.csv
# 2024-02-11 09:55:55 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EAJM_20230104.docx
# 2024-02-11 09:55:55 INFO     Started creating the docx object
# 2024-02-11 09:55:55 INFO     Extracting the properties of the document
# 2024-02-11 09:55:55 INFO     Started processing the components to extract the properties
# 2024-02-11 09:55:56 INFO     Writing the extracted properties into XML
# 2024-02-11 09:55:56 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EAJM_20230104.csv
# 2024-02-11 09:55:56 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/JIRS_20230021.docx
# 2024-02-11 09:55:56 INFO     Started creating the docx object
# 2024-02-11 09:55:56 INFO     Extracting the properties of the document
# 2024-02-11 09:55:56 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:00 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:00 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/JIRS_20230021.csv
# 2024-02-11 09:56:00 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_ecog_06938.docx
# 2024-02-11 09:56:00 INFO     Started creating the docx object
# 2024-02-11 09:56:00 INFO     Extracting the properties of the document
# 2024-02-11 09:56:00 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:00 WARNING  Error extracting properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_ecog_06938.docx: '_CharacterStyle' object has no attribute 'paragraph_format'
# 2024-02-11 09:56:00 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ESE_202303445.docx
# 2024-02-11 09:56:00 INFO     Started creating the docx object
# 2024-02-11 09:56:01 INFO     Extracting the properties of the document
# 2024-02-11 09:56:01 INFO     Started processing the components to extract the properties
# Error while fetching the left indent information from para: '_CharacterStyle' object has no attribute 'paragraph_format'
# Error while fetching the right indent information from para: '_CharacterStyle' object has no attribute 'paragraph_format'
# Error while fetching the right indent information from para: '_CharacterStyle' object has no attribute 'paragraph_format'
# 2024-02-11 09:56:01 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:01 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ESE_202303445.csv
# 2024-02-11 09:56:01 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EDM_230086.docx
# 2024-02-11 09:56:01 INFO     Started creating the docx object
# 2024-02-11 09:56:01 INFO     Extracting the properties of the document
# 2024-02-11 09:56:01 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:04 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:04 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EDM_230086.csv
# 2024-02-11 09:56:04 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TBE_20230001.docx
# 2024-02-11 09:56:04 INFO     Started creating the docx object
# 2024-02-11 09:56:04 INFO     Extracting the properties of the document
# 2024-02-11 09:56:04 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:04 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:04 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TBE_20230001.csv
# 2024-02-11 09:56:04 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ECC_230420.docx
# 2024-02-11 09:56:04 INFO     Started creating the docx object
# 2024-02-11 09:56:04 INFO     Extracting the properties of the document
# 2024-02-11 09:56:04 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:09 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:09 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ECC_230420.csv
# 2024-02-11 09:56:09 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/AP_20231401.docx
# 2024-02-11 09:56:09 INFO     Started creating the docx object
# 2024-02-11 09:56:09 INFO     Extracting the properties of the document
# 2024-02-11 09:56:09 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:10 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:10 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/AP_20231401.csv
# 2024-02-11 09:56:10 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/NanoEra_20240001.docx
# 2024-02-11 09:56:10 INFO     Started creating the docx object
# 2024-02-11 09:56:10 INFO     Extracting the properties of the document
# 2024-02-11 09:56:10 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:10 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:10 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/NanoEra_20240001.csv
# 2024-02-11 09:56:10 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/JIAO_20231228.docx
# 2024-02-11 09:56:10 INFO     Started creating the docx object
# 2024-02-11 09:56:10 INFO     Extracting the properties of the document
# 2024-02-11 09:56:10 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:12 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:12 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/JIAO_20231228.csv
# 2024-02-11 09:56:12 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EOR_230151.docx
# 2024-02-11 09:56:12 INFO     Started creating the docx object
# 2024-02-11 09:56:12 INFO     Extracting the properties of the document
# 2024-02-11 09:56:12 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:14 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:14 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EOR_230151.csv
# 2024-02-11 09:56:14 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ED_20230014.docx
# 2024-02-11 09:56:14 INFO     Started creating the docx object
# 2024-02-11 09:56:14 INFO     Extracting the properties of the document
# 2024-02-11 09:56:14 INFO     Started processing the components to extract the properties
# 2024-02-11 09:56:14 INFO     Writing the extracted properties into XML
# 2024-02-11 09:56:14 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ED_20230014.csv
# 2024-02-11 09:56:14 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/ABCR_20230184.docx
# 2024-02-11 09:56:15 INFO     Started creating the docx object
# 2024-02-11 09:56:15 INFO     Extracting the properties of the document
# 2024-02-11 09:56:15 INFO     Started processing the components to extract the properties
# 2024-02-11 10:04:46 INFO     Writing the extracted properties into XML
# 2024-02-11 10:04:46 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/ABCR_20230184.csv
# 2024-02-11 10:04:46 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EAJM_20230145.docx
# 2024-02-11 10:04:46 INFO     Started creating the docx object
# 2024-02-11 10:04:46 INFO     Extracting the properties of the document
# 2024-02-11 10:04:46 INFO     Started processing the components to extract the properties
# 2024-02-11 10:04:49 INFO     Writing the extracted properties into XML
# 2024-02-11 10:04:49 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EAJM_20230145.csv
# 2024-02-11 10:04:49 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TR_20230318.docx
# 2024-02-11 10:04:49 INFO     Started creating the docx object
# 2024-02-11 10:04:49 INFO     Extracting the properties of the document
# 2024-02-11 10:04:49 INFO     Started processing the components to extract the properties
# 2024-02-11 10:04:51 INFO     Writing the extracted properties into XML
# 2024-02-11 10:04:51 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TR_20230318.csv
# 2024-02-11 10:04:51 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TJN_20230510.docx
# 2024-02-11 10:04:51 INFO     Started creating the docx object
# 2024-02-11 10:04:51 INFO     Extracting the properties of the document
# 2024-02-11 10:04:51 INFO     Started processing the components to extract the properties
# 2024-02-11 10:04:54 INFO     Writing the extracted properties into XML
# 2024-02-11 10:04:54 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TJN_20230510.csv
# 2024-02-11 10:04:54 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/AJC_20234060.docx
# 2024-02-11 10:04:54 INFO     Started creating the docx object
# 2024-02-11 10:04:54 INFO     Extracting the properties of the document
# 2024-02-11 10:04:54 INFO     Started processing the components to extract the properties
# 2024-02-11 10:04:54 INFO     Writing the extracted properties into XML
# 2024-02-11 10:04:54 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/AJC_20234060.csv
# 2024-02-11 10:04:54 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/OIKOS_ecog_06979.docx
# 2024-02-11 10:04:55 INFO     Started creating the docx object
# 2024-02-11 10:04:55 INFO     Extracting the properties of the document
# 2024-02-11 10:04:55 INFO     Started processing the components to extract the properties
# 2024-02-11 10:05:01 INFO     Writing the extracted properties into XML
# 2024-02-11 10:05:01 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/OIKOS_ecog_06979.csv
# 2024-02-11 10:05:02 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/EAJM_20230329.docx
# 2024-02-11 10:05:02 INFO     Started creating the docx object
# 2024-02-11 10:05:02 INFO     Extracting the properties of the document
# 2024-02-11 10:05:02 INFO     Started processing the components to extract the properties
# 2024-02-11 10:05:08 INFO     Writing the extracted properties into XML
# 2024-02-11 10:05:08 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/EAJM_20230329.csv
# 2024-02-11 10:05:08 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/AJC_AJC-2023-382_R1RESUBMISSION-3517.docx
# 2024-02-11 10:05:08 INFO     Started creating the docx object
# 2024-02-11 10:05:08 INFO     Extracting the properties of the document
# 2024-02-11 10:05:08 INFO     Started processing the components to extract the properties
# 2024-02-11 10:05:17 INFO     Writing the extracted properties into XML
# 2024-02-11 10:05:17 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/AJC_AJC-2023-382_R1RESUBMISSION-3517.csv
# 2024-02-11 10:05:17 INFO     Started to extract the docx properties from /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/TJN_20230639.docx
# 2024-02-11 10:05:17 INFO     Started creating the docx object
# 2024-02-11 10:05:17 INFO     Extracting the properties of the document
# 2024-02-11 10:05:17 INFO     Started processing the components to extract the properties
# 2024-02-11 10:05:21 INFO     Writing the extracted properties into XML
# 2024-02-11 10:05:21 INFO     Converting properties XML to CSV: /Users/senthil/Downloads/JPT/journals_data_element_prediction/dataset prep/updated_docx/dataset/TJN_20230639.csv
